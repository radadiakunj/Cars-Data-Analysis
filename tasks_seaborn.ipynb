# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
frd = pd.read_csv("ford.csv")

# %%
frd
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1        Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2        Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3       Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4       Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...        ...   ...    ...          ...      ...      ...  ...   ...
# 17960   Fiesta  2016   7999       Manual    31348   Petrol  125  54.3
# 17961    B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962    B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963    Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964       KA  2018   8299       Manual     5007   Petrol  145  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...

# %%
frd.fillna(0,axis=1,inplace=True)

# %% [markdown]
# **pd.pivot_table(Data,index,columns,values)**

# %%
pt = pd.pivot_table(frd,index="mileage",columns="fuelType",values="price")

# %%
pt
# Out:
# fuelType   Diesel Electric Hybrid Other        Petrol
# mileage
# 1         17558.0      NaN    NaN   NaN  13296.666667
# 2         19480.0      NaN    NaN   NaN           NaN
# 4             NaN      NaN    NaN   NaN       17550.0
# 5         16410.0      NaN    NaN   NaN       15120.0
# 6             NaN      NaN    NaN   NaN     13803.625
# ...           ...      ...    ...   ...           ...
# 144000     2400.0      NaN    NaN   NaN           NaN
# 150890     5795.0      NaN    NaN   NaN           NaN
# 151000     3495.0      NaN    NaN   NaN           NaN
# 174000     3995.0      NaN    NaN   NaN           NaN
# 177644        NaN      NaN    NaN   NaN         495.0
#
# [13528 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame({
    'model': ['Fiesta', 'Focus', 'Focus', 'Fiesta', 'Fiesta'],
    'year': [2017, 2018, 2017, 2019, 2019],
    'price': [12000, 14000, 13000, 17500, 16500],
    'transmission': ['Automatic', 'Manual', 'Manual', 'Manual', 'Automatic'],
    'mileage': [15944, 9083, 12456, 10460, 1482],
    'fuelType': ['Petrol', 'Petrol', 'Petrol', 'Petrol', 'Petrol'],
    'tax': [150, 150, 150, 145, 145],
    'mpg': [57.7, 57.7, 57.7, 40.3, 48.7],
    'engineSize': [1.0, 1.0, 1.0, 1.5, 1.0]
})

# Select numerical columns for correlation
numerical_cols = ['year', 'price', 'mileage', 'tax', 'mpg', 'engineSize']
numerical_data = df[numerical_cols]

# Create correlation matrix
corr_matrix = numerical_data.corr()

# Create heatmap
sns.heatmap(corr_matrix, annot=True, cmap='rocket')

plt.show()

# %%
df
# Out:
#     model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0  Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1   Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2   Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3  Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4  Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
corr_matrix
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.966012 -0.767673 -0.912871 -0.844407    0.559017
# price       0.966012  1.000000 -0.674564 -0.940634 -0.927764    0.696022
# mileage    -0.767673 -0.674564  1.000000  0.666637  0.391612    0.059972
# tax        -0.912871 -0.940634  0.666637  1.000000  0.925001   -0.612372
# mpg        -0.844407 -0.927764  0.391612  0.925001  1.000000   -0.866833
# engineSize  0.559017  0.696022  0.059972 -0.612372 -0.866833    1.000000

# %%
df1 = pd.read_csv("bmw.csv")

# %%
df1
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3       1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic    40818   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# ...

# %%
import pandas as pd

df = pd.DataFrame({
    'model': ['5 Series', '6 Series', '5 Series', '1 Series'],
    'year': [2014, 2018, 2016, 2017],
    'price': [11200, 27000, 16000, 12750],
    'transmission': ['Automatic', 'Automatic', 'Automatic', 'Automatic'],
    'mileage': [67068, 14827, 62794, 26676],
    'fuelType': ['Diesel', 'Petrol', 'Diesel', 'Diesel'],
    'tax': [125, 145, 160, 145],
    'mpg': [57.6, 42.8, 51.4, 72.4],
    'engineSize': [2.0, 2.0, 3.0, 1.5],
})

# Convert 'model' column from string to float
df['model'] = df['model'].str.extract('(\d+)', expand=False).astype(str)

print(df)
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0     5  2014  11200    Automatic    67068   Diesel  125  57.6         2.0
# 1     6  2018  27000    Automatic    14827   Petrol  145  42.8         2.0
# 2     5  2016  16000    Automatic    62794   Diesel  160  51.4         3.0
# 3     1  2017  12750    Automatic    26676   Diesel  145  72.4         1.5

# %%
sns.pairplot(df1)
# Out:
# C:\Users\ADMIN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df1)
# Out:
# C:\Users\ADMIN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(df1)
# Out:
# C:\Users\ADMIN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(df1)
# Out:
# <Axes: >

# %%
sns.histplot(df1)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(df1["year"])
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
## represents the relationship between a categorical variable and a continuous variable
sns.boxplot(df1["price"])
# Out:
# <Axes: >

# %%
sns.distplot(df1["price"])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_5664\3616304564.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1["price"])
# <Axes: xlabel='price', ylabel='Density'>

# %%
df1["price"].skew()
# Out:
# 1.5595528121107132

# %%
sns.displot(df1["price"])
# Out:
# C:\Users\ADMIN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
## displays the kernel density estimate of the data
sns.violinplot(df1["price"])
# Out:
# <Axes: >

# %%
sns.pointplot(df1["price"])
# Out:
# <Axes: >
